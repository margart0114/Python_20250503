# %% [markdown]
# <a href="https://colab.research.google.com/github/margart0114/Python_20250503/blob/main/lesson2/lesson2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 只有數值型別可以數學運算

# %%
5 + 5
5.0 + 5.0
5 + 5.0
# Out:
# 10.0

# %% [markdown]
# ### 數值和字串無法數學運算
#
# ### 閃退
# ##### TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
5 + "5"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b265071c056c> in <cell line: 0>()
# ----> 1 5 + "5"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### 字串和字串可以相加，相乘

# %%
"5"+"5"
"="*10
# Out:
# '=========='

# %% [markdown]
# ### 暫時轉換型別

# %%
5 + float("5")
# Out:
# 10.0

# %%
width = float(input("請輸入矩型的寬:"))
height = float(input("請輸入矩形的高:"))
area = width * height
print("矩形的面積為:",area)
# Out:
# 請輸入矩型的寬:4.678
# 請輸入矩形的高:9.257
# 矩形的面積為: 43.304246
